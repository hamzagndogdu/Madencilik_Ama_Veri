# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')

# %%
model_2 = YOLO('yolov8l.pt')
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 83.7M/83.7M [01:09<00:00, 1.27MB/s]

# %%
import torch
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 2060'

# %%
model.train(
    data='data.yaml',          
    epochs=250,                 
    imgsz=640,                 
    batch=8,                  
    workers=4,                 
    device=0                   
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.52 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.36  Python-3.10.9 torch-2.4.1+cu124 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %%
model_2.train(
    data='data.yaml',          
    epochs=100,                 
    imgsz=640,                 
    batch=8,                  
    workers=4,                 
    device=0                   
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.52 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.36  Python-3.10.9 torch-2.4.1+cu124 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics 8.3.36  Python-3.10.9 torch-2.4.1+cu124 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 168 layers, 3,016,568 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\labels.cache.
# val: WARNING  C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141301.jpg: corrupt JPEG restored and saved
# val: WARNING  C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141333.jpg: corrupt JPEG restored and saved
# val: WARNING  C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141402.jpg: corrupt JPEG restored and saved
# val: WARNING  C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141618.jpg: corrupt JPEG restored and saved
# ...

# %%
metrics_2 = model_2.val()
# Out:
# Ultralytics 8.3.36  Python-3.10.9 torch-2.4.1+cu124 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Model summary (fused): 268 layers, 43,649,784 parameters, 0 gradients, 165.1 GFLOPs
# val: Scanning C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\labels.cache.
# val: WARNING  C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141301.jpg: corrupt JPEG restored and saved
# val: WARNING  C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141333.jpg: corrupt JPEG restored and saved
# val: WARNING  C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141402.jpg: corrupt JPEG restored and saved
# val: WARNING  C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141618.jpg: corrupt JPEG restored and saved
# ...

# %%
model.export(format='onnx')
# Out:
# Ultralytics 8.3.36  Python-3.10.9 torch-2.4.1+cu124 CPU (Intel Core(TM) i7-10750H 2.60GHz)
#
# PyTorch: starting from 'runs\detect\train5\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 60, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['onnxslim', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Retry 1/2 failed: Command 'pip install --no-cache-dir "onnxslim" "onnxruntime-gpu" ' returned non-zero exit status 2.
# Retry 2/2 failed: Command 'pip install --no-cache-dir "onnxslim" "onnxruntime-gpu" ' returned non-zero exit status 2.
# requirements:  Command 'pip install --no-cache-dir "onnxslim" "onnxruntime-gpu" ' returned non-zero exit status 2.
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: simplifier failure: No module named 'onnxslim'
# ONNX: export success  160.6s, saved as 'runs\detect\train5\weights\best.onnx' (11.7 MB)
#
# Export complete (160.8s)
# ...

# %%
model_2.export(format='onnx')
# Out:
# Ultralytics 8.3.36  Python-3.10.9 torch-2.4.1+cu124 CPU (Intel Core(TM) i7-10750H 2.60GHz)
#
# PyTorch: starting from 'runs\detect\train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 60, 8400) (83.6 MB)
# requirements: Ultralytics requirements ['onnxslim', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.45...
# ONNX: export success  380.7s, saved as 'runs\detect\train\weights\best.onnx' (166.8 MB)
#
# Export complete (382.1s)
# Results saved to C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\runs\detect\train\weights
# Predict:         yolo predict task=detect model=runs\detect\train\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs\detect\train\weights\best.onnx imgsz=640 data=data.yaml
# Visualize:       https://netron.app
# 'runs\\detect\\train\\weights\\best.onnx'

# %%
# 7. Model Test Et
# Tek bir görüntü ile test edebilirsiniz
results = model.predict(source= "Output/Validation/images", save=True, conf=0.25)
print(results)
# Out:
# image 1/85 C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141301.jpg: 640x480 1 Tarhana, 1 Besamelli Tavuk, 1 Makarna, 49.0ms
# image 2/85 C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141333.jpg: 640x480 1 Tarhana, 1 Besamelli Tavuk, 1 Makarna, 1 Pirinc Pilavi, 36.5ms
# image 3/85 C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141402.jpg: 640x480 1 Tarhana, 1 Besamelli Tavuk, 1 Bulgur Pilavi, 37.8ms
# image 4/85 C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141618.jpg: 640x480 1 Tarhana, 1 Bulgur Pilavi, 1 Manti, 37.4ms
# image 5/85 C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141705.jpg: 640x480 1 Tarhana, 1 Makarna, 1 Manti, 1 Ekmek, 37.1ms
# ...

# %%
# 7. Model Test Et
# Tek bir görüntü ile test edebilirsiniz
results = model_2.predict(source= "Output/Validation/images", save=True, conf=0.25)
print(results)
# Out:
# image 1/85 C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141301.jpg: 640x480 2 Tarhanas, 1 Besamelli Tavuk, 1 Makarna, 1 Enginar, 46.9ms
# image 2/85 C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141333.jpg: 640x480 1 Tarhana, 1 Besamelli Tavuk, 1 Pirinc Pilavi, 46.9ms
# image 3/85 C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141402.jpg: 640x480 1 Tarhana, 1 Besamelli Tavuk, 1 Enginar, 1 Bulgur Pilavi, 31.3ms
# image 4/85 C:\Aile Efradi\Hamza Gundogdu\Fourth_Class_Works\Veri Madenciligi\Dataset\Output\Validation\images\20241210_141618.jpg: 640x480 1 Tarhana, 1 Bulgur Pilavi, 1 Manti, 46.9ms
# ...

# %%
model.save("model.pt")

# %%
model_2.save("model_2.pt")
